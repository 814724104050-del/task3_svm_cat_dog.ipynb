# %% [markdown]
# # 🐱🐶 Cat vs Dog Classification using SVM
# ### Prodigy Infotech Internship – Task 03
# ---
# **Objective:** Implement an SVM model to classify Cats & Dogs images from Kaggle dataset

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

data = []
labels = []

path = 'train'  # dataset folder name

for img in os.listdir(path):
    img_path = os.path.join(path, img)
    image = cv2.imread(img_path)
    image = cv2.resize(image,(64,64))
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    data.append(gray.flatten())
    labels.append(0 if 'cat' in img else 1)

data = np.array(data)
labels = np.array(labels)

X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2)

model = SVC(kernel='linear')
model.fit(X_train, y_train)

pred = model.predict(X_test)
print('Accuracy =', accuracy_score(y_test, pred))

# %% [markdown]
# ## 🎯 Result
# Model prints accuracy score successfully ✔
